# %%
#webscrapping segment
import requests,bs4,webbrowser

#imdb actor page 
actor = input('Enter the actor name: ')
res = requests.get('https://www.imdb.com/find?q='+actor.replace('','+'))
res.raise_for_status()
soup = bs4.BeautifulSoup(res.text)
soupelem = soup.select('.result_text a')
#webbrowser.open('https://www.imdb.com/'+soupelem[0].get('href'))
actorpage = requests.get('https://www.imdb.com'+soupelem[0].get('href'))
actorpage.raise_for_status()

#actor page soup
soup = bs4.BeautifulSoup(actorpage.text)

#actor info
actorName = soup.select('.header .itemprop')[0].text
actorJobs = list(map(lambda name: name.text[1:],soup.select('#name-job-categories a span')))
actorPhoto = soup.select('#name-poster')[0].get('src')
actorPhotoPath = actorPhoto.split('/')[-1]
# actorDescription = soup.select('.name-trivia-bio-text .inline')[0]
# print(actorDescription.text.split('...')[0])
actorBDsoup = soup.select('#name-born-info')[0]
actorBD = ' '.join(list(map(lambda text:text.strip(),actorBDsoup.text.split('\n'))))
print(actorJobs)


#all the movies of the actor
soupelem = soup.select('#filmo-head-actor + .filmo-category-section .filmo-row')
#print(soupelem[2].text.split('\n'))

print('\n')
for movies in soupelem:
    movieYear = movies.select('.year_column')[0].text
    movieTitle = movies.select('b a')[0].text
    print(movieTitle+' in '+movieYear)
# Out:
# Enter the actor name: tom holland
# ['Actor', 'Producer', 'Director']
#
#
# Untitled Fred Astaire Biopic in
#
#
# Uncharted in
#  2022
#
# The Daily Bugle in
#  2021
#
# Spider-Man: No Way Home in
#  2021
#
# Venom: Let There Be Carnage in
#  2021
#
# Cherry in
#  2021/I
#
# Chaos Walking in
#  2021
#
# The Devil All the Time in
#  2020
#
# Onward: Magic Gems in
#  2020
#
# Onward in
#  2020/I
#
# Dolittle in
#  2020
#
# Spies in Disguise in
#  2019
#
# Audi Presents: Lunch Break in
#  2019
#
# Peter's To-Do List in
#  2019
#
# Spider-Man: Far from Home in
#  2019
#
# Science Fair in
#  2019
#
# Avengers: Endgame in
#  2019
#
# Avengers: Infinity War in
#  2018
#
# The Current War in
#  2017
#
# Peter Parker Takes His Driving Test in
#  2017
#
# Spider-Man: Homecoming in
#  2017
#
# Spider-Man: Homecoming, NBA Finals: Watch the Game in
#  2017
#
# Pilgrimage in
#  2017/II
#
# The Lost City of Z in
#  2016
#
# Edge of Winter in
#  2016
#
# Captain America: Civil War in
#  2016
#
# In the Heart of the Sea in
#  2015
#
# Tweet in
#  2015
#
# Wolf Hall in
#  2015
#
# Billy Elliot: The Musical Live in
#  2014
#
# How I Live Now in
#  2013
#
# Locke in
#  2013
#
# Moments in
#  2013/VI
#
# Lo imposible in
#  2012
#
# Kari-gurashi no Arietti in
#  2010

# %%
#excel segment
import openpyxl
from openpyxl.cell import get_column_letter

wb = openpyxl.Workbook()
sheet = wb.get_active_sheet()
sheet['A1'].value = 'Title'
sheet['B1'].value = 'Year'

for row in range(2,11):
    for col in range(1,3):
        colLet = get_column_letter(col)
        sheet[colLet+str(row)]=colLet+str(row)

wb.save('bleh.xlsx')

# %%
#image download segment
import os
os.makedirs('photos',exist_ok=True)
res = requests.get(actorPhoto)
imageFile = open(os.path.join('photos',os.path.basename(actorPhoto)),'wb')

for chunk in res.iter_content(100000):
    imageFile.write(chunk)
imageFile.close()

# %%
#docx segment
import docx,os

doc = docx.Document()
doc.add_paragraph(actorName,'Title')
doc.add_picture('./photos/'+actorPhotoPath,width=docx.shared.Cm(5))
doc.add_paragraph('Actor Jobs: '+', '.join(actorJobs))
doc.add_paragraph(actorBD)

doc.save('actordesc.docx')

# %%
#ADP PROJECT
import requests,bs4
import openpyxl
import docx,os

#imdb actor page 
actor = input('Enter the actor name: ')
res = requests.get('https://www.imdb.com/find?q='+actor.replace('','+'))
res.raise_for_status()
soup = bs4.BeautifulSoup(res.text)
soupelem = soup.select('.result_text a')
actorpage = requests.get('https://www.imdb.com'+soupelem[0].get('href'))
actorpage.raise_for_status()

#actor page soup
soup = bs4.BeautifulSoup(actorpage.text)

#actor info
actorName = soup.select('.header .itemprop')[0].text
actorJobs = list(map(lambda name: name.text[1:],soup.select('#name-job-categories a span')))
actorPhoto = soup.select('#name-poster')[0].get('src')
actorPhotoPath = actorPhoto.split('/')[-1]
# actorDescription = soup.select('.name-trivia-bio-text .inline')[0]
# print(actorDescription.text.split('...')[0])
actorBDsoup = soup.select('#name-born-info')[0]
actorBD = ' '.join(list(map(lambda text:text.strip(),actorBDsoup.text.split('\n'))))
print(actorJobs)

#all the movies of the actor
soupelem = soup.select('#filmo-head-actor + .filmo-category-section .filmo-row')

# wb = openpyxl.Workbook()
# sheet = wb.get_active_sheet()
# sheet['A1'].value = 'Title'
# sheet['B1'].value = 'Year'

# for movies in soupelem:
#     movieYear = movies.select('.year_column')[0].text
#     movieTitle = movies.select('b a')[0].text
#     print(movieTitle+' in '+movieYear)
    

wb = openpyxl.Workbook()
sheet = wb.get_active_sheet()
sheet['A1'].value = 'Title'
sheet['B1'].value = 'Year'

for row in range(2,len(soupelem)+2):
    movie = soupelem[row-2]
    sheet['A'+str(row)]=movie.select('b a')[0].text
    sheet['B'+str(row)]=movie.select('.year_column')[0].text[:6]
    
os.makedirs('photos',exist_ok=True)
res = requests.get(actorPhoto)
imageFile = open(os.path.join('photos',os.path.basename(actorPhoto)),'wb')

for chunk in res.iter_content(100000):
    imageFile.write(chunk)
imageFile.close()

doc = docx.Document()
doc.add_paragraph(actorName,'Title')
doc.add_picture('./photos/'+actorPhotoPath,width=docx.shared.Cm(5))
doc.add_paragraph('Actor Jobs: '+', '.join(actorJobs))
doc.add_paragraph(actorBD)


wb.save('actorMovies.xlsx')
doc.save('actordesc.docx')
print('success!')
# Out:
# Enter the actor name: john krasinski
# ['Actor', 'Producer', 'Director']
# success!
